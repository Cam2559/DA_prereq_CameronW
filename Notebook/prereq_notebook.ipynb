# %%
print("Hello to you!")

# %% [markdown]
# Hi, my name is Cameron Walters. I am so excited to learn python and improve my own technical skills. I have always enjoyed working with and troubleshooting computers, but with my current experenice I would be considered a hobbisty by most employeers, though I have held Help Desk jobs in the past I did not feel they allowed me to apply what skills I do have outside of the basic troubleshootiing of Windows and Mac OS. I wish to persue a career as a Data Analys to further my skills and of course break into a bigger role in the feild that will allow me to continue developing my own skills and allow me new opportunities in life! I mostly have experince with server maintenance as I had taken Cisco courses durring High School, though due to Covid I was unable to get the CCNA at the time and before I knew it I found myself in a position no longer able to get it. Durring my time at college I had work with some C+ programing for basic LED arrays and simple arduino projects, but felt that I wasn't where I want to be. In the end I had left and found myself lost and unsure of where or what feild I wanted to be in. Then I heard of Code:You and decided to give it a shot! Unfortunately, I had chosen the C# for Software Dev's and realized I "bit off more than I could chew", so to say. After many videos and looking over the offered corses I decided this would be perfect for me and I hope that I can deliever great projects moving forward!
